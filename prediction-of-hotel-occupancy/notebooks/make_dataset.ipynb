# %%
import pandas as pd
import os
import csv
import glob
from datetime import datetime
from functools import reduce

# %%
WEATHER_DATA_BASE_PATH = '../data/external/weather_data'
HOLIDAYS_BASE_PATH = '../data/external/holidays'

# %% [markdown]
# # Kreiranje podatkovnog okvira za vremensku prognozu

# %%
lisbon_weather_data_2015 = pd.read_csv(os.path.join(WEATHER_DATA_BASE_PATH, 'lisbon\\lisbon_weather_data_2015.csv'))
lisbon_weather_data_2016 = pd.read_csv(os.path.join(WEATHER_DATA_BASE_PATH, 'lisbon\\lisbon_weather_data_2016.csv'))
lisbon_weather_data_2017 = pd.read_csv(os.path.join(WEATHER_DATA_BASE_PATH, 'lisbon\\lisbon_weather_data_2017.csv'))

# %%
algarve_weather_data_2015 = pd.read_csv(os.path.join(WEATHER_DATA_BASE_PATH, 'algarve\\algarve_weather_data_2015.csv'))
algarve_weather_data_2016 = pd.read_csv(os.path.join(WEATHER_DATA_BASE_PATH, 'algarve\\algarve_weather_data_2016.csv'))
algarve_weather_data_2017 = pd.read_csv(os.path.join(WEATHER_DATA_BASE_PATH, 'algarve\\algarve_weather_data_2017.csv'))

# %%
lisbon_weather_data_2015.describe()
# Out:
#           tempmax     tempmin        temp  feelslikemax  feelslikemin  \
# count  365.000000  365.000000  365.000000    365.000000    365.000000
# mean    21.684110   13.863562   17.253699     21.635342     13.483562
# std      5.863551    4.166106    4.670161      5.806749      4.815748
# min      7.200000    1.200000    4.100000      7.200000     -2.200000
# 25%     17.000000   11.000000   13.900000     17.000000     11.000000
# 50%     21.100000   14.300000   17.300000     21.100000     14.300000
# 75%     26.400000   17.100000   21.100000     26.400000     17.100000
# max     35.300000   23.400000   27.400000     35.200000     23.400000
#
#         feelslike         dew    humidity      precip  precipprob  ...  \
# count  365.000000  365.000000  365.000000  365.000000  365.000000  ...
# mean    17.101918   11.299178   70.715342    0.944364   31.780822  ...
# std      4.903830    3.956657   13.566439    3.862379   46.626363  ...
# ...

# %%
lisbon_weather_data_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              365 non-null    object
#  1   datetime          365 non-null    object
#  2   tempmax           365 non-null    float64
#  3   tempmin           365 non-null    float64
#  4   temp              365 non-null    float64
#  5   feelslikemax      365 non-null    float64
#  6   feelslikemin      365 non-null    float64
#  7   feelslike         365 non-null    float64
#  8   dew               365 non-null    float64
#  9   humidity          365 non-null    float64
#  10  precip            365 non-null    float64
#  11  precipprob        365 non-null    int64
#  12  precipcover       365 non-null    float64
#  13  preciptype        116 non-null    object
#  14  snow              0 non-null      float64
#  15  snowdepth         0 non-null      float64
# ...

# %%
lisbon_weather_data_2015.merge(lisbon_weather_data_2016, how='outer').merge(lisbon_weather_data_2017, how='outer').to_csv(os.path.join(WEATHER_DATA_BASE_PATH, 'lisbon\\lisbon_weather_data.csv'), index=False)

# %%
algarve_weather_data_2015.merge(algarve_weather_data_2016, how='outer').merge(algarve_weather_data_2017, how='outer').to_csv(os.path.join(WEATHER_DATA_BASE_PATH, 'algarve\\algarve_weather_data.csv'), index=False)
# Out:
# C:\Temp\ipykernel_27548\2764141123.py:1: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   algarve_weather_data_2015.merge(algarve_weather_data_2016, how='outer').merge(algarve_weather_data_2017, how='outer').to_csv(os.path.join(WEATHER_DATA_BASE_PATH, 'algarve\\algarve_weather_data.csv'), index=False)

# %% [markdown]
# # Kreiranje podatkovnog okvira za praznike

# %%
all_holidays = {}

for country in os.listdir(HOLIDAYS_BASE_PATH):
    if os.path.isdir(os.path.join(HOLIDAYS_BASE_PATH, country)):
        all_holidays[country] = {}
        for year_file in glob.glob(os.path.join(HOLIDAYS_BASE_PATH, country, "*.txt")):
            try:
                year = os.path.basename(year_file).split('.')[0]
                all_holidays[country][year] = []

                with open(year_file, mode='r', encoding='utf-8') as file:
                    reader = csv.reader(file)
                    headers = next(reader)
                    date_idx = headers.index("Date")
                    name_idx = headers.index("Name")
                    type_idx = headers.index("Type")

                    for row in reader:

                        date = row[date_idx]
                        date = datetime.strptime(f'{date} {year}', '%d %b %Y')
                        date= date.strftime('%Y-%m-%d') 
                        name = row[name_idx]
                        type_ = row[type_idx]
                        all_holidays[country][year].append([date, name, type_])

            except Exception as e:
                print(f"Error prcessing file: {year_file}\nError: {e}")

# %%
holiday_portugal = pd.DataFrame(all_holidays['portugal']['2015'] + all_holidays['portugal']['2016'] + all_holidays['portugal']['2017'], columns=['date', 'name', 'type'])
holiday_portugal.to_csv(os.path.join(HOLIDAYS_BASE_PATH, 'portugal\\holidays.csv'), index=False)

# %%
holiday_france = pd.DataFrame(all_holidays['france']['2015'] + all_holidays['france']['2016'] + all_holidays['france']['2017'], columns=['date', 'name', 'type'])
holiday_france.to_csv(os.path.join(HOLIDAYS_BASE_PATH, 'france\\holidays.csv'), index=False)

# %%
holiday_germany = pd.DataFrame(all_holidays['germany']['2015'] + all_holidays['germany']['2016'] + all_holidays['germany']['2017'], columns=['date', 'name', 'type'])
holiday_germany.to_csv(os.path.join(HOLIDAYS_BASE_PATH, 'germany\\holidays.csv'), index=False)

# %%
holiday_italy = pd.DataFrame(all_holidays['italy']['2015'] + all_holidays['italy']['2016'] + all_holidays['italy']['2017'], columns=['date', 'name', 'type'])
holiday_italy.to_csv(os.path.join(HOLIDAYS_BASE_PATH, 'italy\\holidays.csv'), index=False)

# %%
holiday_spain = pd.DataFrame(all_holidays['spain']['2015'] + all_holidays['spain']['2016'] + all_holidays['spain']['2017'], columns=['date', 'name', 'type'])
holiday_spain.to_csv(os.path.join(HOLIDAYS_BASE_PATH, 'spain\\holidays.csv'), index=False)

# %%
holiday_united_kingdom = pd.DataFrame(all_holidays['united_kingdom']['2015'] + all_holidays['united_kingdom']['2016'] + all_holidays['united_kingdom']['2017'], columns=['date', 'name', 'type'])
holiday_united_kingdom.to_csv(os.path.join(HOLIDAYS_BASE_PATH, 'united_kingdom\\holidays.csv'), index=False)

# %% [markdown]
# ### Finding the intersection of the holidays

# %%
holiday_intersection = holiday_portugal[['date', 'name', 'type']]
holiday_intersection = holiday_intersection.merge(holiday_france[['date']], how='inner', on='date')
holiday_intersection = holiday_intersection.merge(holiday_germany[['date']], how='inner', on='date')
holiday_intersection = holiday_intersection.merge(holiday_italy[['date']], how='inner', on='date')
holiday_intersection = holiday_intersection.merge(holiday_spain[['date']], how='inner', on='date')
holiday_intersection = holiday_intersection.merge(holiday_united_kingdom[['date']], how='inner', on='date')

# %%
holiday_intersection.to_csv(os.path.join(HOLIDAYS_BASE_PATH, 'holidays_intersection.csv'), index=False)
